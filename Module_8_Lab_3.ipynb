# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshman142/FMML_Assignments/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-14 09:08:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   185MB/s    in 0.4s
#
# 2023-05-14 09:08:35 (185 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20549  1606.04589v1  With the aim of studying social properties of ...    cs
# 6220   1609.07272v1  Semi-supervised clustering methods incorporate...  stat
# 25840  1511.09207v2  Different from focused texts present in natura...    cs
# 13958  1611.04766v1  We introduce the use of high order automatic d...    cs
# 4367   1606.08288v1  High predictive performance and ease of use an...  stat
# ...             ...                                                ...   ...
# 22952  1711.08042v2  Most research on the interpretability of machi...  stat
# 33714  1602.02656v1  Recent developments in speech synthesis have p...    cs
# 32193   1206.5915v1  In this paper we consider the problem of colle...    cs
# 25938  1512.06559v2  Retinal images provide early signs of diabetic...    cs
# 38798   1303.6361v1  Balancing computational efficiency with recogn...    cs
#
#                                                    title  year  \
# 20549                    Impossibility in Belief Merging  2016
# 6220               Constraint-Based Clustering Selection  2016
# 25840  Incidental Scene Text Understanding: Recent Pr...  2015
# 13958                 Differentiable Genetic Programming  2016
# 4367   Interpreting extracted rules from ensemble of ...  2016
# ...                                                  ...   ...
# 22952  "I know it when I see it". Visualization and I...  2017
# 33714  LSTM Deep Neural Networks Postfiltering for Im...  2016
# 32193  Graph Based Classification Methods Using Inacc...  2012
# 25938  Analysis of Vessel Connectivities in Retinal I...  2015
# 38798  Video Face Matching using Subset Selection and...  2013
#
#                                                 keywords
# 20549  [properties, understanding, impossibility, fra...
# 6220   [supervised, clustering, incorporate, supervis...
# 25840  [different, intention, intervention, incidenta...
# 13958  [introduce, automatic, differentiation, implem...
# 4367   [predictive, performance, interpretability, im...
# ...                                                  ...
# 22952  [interpretability, development, interpretabili...
# 33714  [developments, synthesis, intelligible, resear...
# 32193  [collectively, classifying, relational, inform...
# 25938  [retinopathy, hypertension, investigated, micr...
# 38798  [balancing, computational, efficiency, recogni...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20549    [properties, understanding, impossibility, fra...
# 6220     [supervised, clustering, incorporate, supervis...
# 25840    [different, intention, intervention, incidenta...
# 13958    [introduce, automatic, differentiation, implem...
# 4367     [predictive, performance, interpretability, im...
#                                ...
# 20284    [computing, assignments, variables, propositio...
# 838      [exploration, environments, persistent, reinfo...
# 35017    [investigate, multipleoutput, broadcast, trans...
# 30663    [connected, components, implemented, following...
# 12999    [algorithm, filtering, developed, nonparametri...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8615 words.
# Out of those 4537 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="76ed2b96-eac1-499c-89c3-bfd2337bd109" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76ed2b96-eac1-499c-89c3-bfd2337bd109")) {                    Plotly.newPlot(                        "76ed2b96-eac1-499c-89c3-bfd2337bd109",                        [{"x":["postulates","different","representation","societies","represented","introduced","framework","properties","functions","multisets","representations","independence","preorders","interesting","epistemic","information","understanding","alternatives","konieczny","operators","irrelevant","classical","extensions","conditionals","conditional","establish","impossibility","essentially","propositional","unsupervised","similarity","supervision","clustering","supervised","algorithms","procedure","constraints","typically","following","individual","selection","approaches","constraint","outperforms","generated","incorporate","clusterings","empirically","parameter","introduce","complexity","intervention","performance","challenging","detection","intention","progresses","dedicated","challenge","diversity","variability","significant","recognition","stimulate","strategies","difficulties","competition","solutions","challenges","regression","demonstrate","equations","increasing","resulting","differential","programming","truncated","propagate","differentiation","constants","automatic","presenting","differentiable","integrals","expressions","cartesian","polynomials","expression","dynamical","implemented","comprehensible","screening","extracted","classification","understand","predictive","application","important","differentiating","interpretability","cancerous","specifically","algorithm","interpreting","radiologist","requirements","diagnosis","multiparametric","visualization","reviewing","applicability","extraction","adaptation","evaluations","transform","classifier","distributions","procedures","embedding","distribution","validation","competitive","alignment","parameters","nonlinear","combining","comprehensive","efficient","quadratic","approximation","evaluation","superiority","stability","approximated","empirical","deviation","particular","computing","extension","structured","extending","situations","construct","scientific","factorization","construction","checkerboard","introducing","artifacts","mechanism","significantly","experiments","effective","reformulated","extensive","uncertainties","delivered","deconvolution","contribution","uncertain","favorably","encourage","convolutional","robustness","upsampling","inference","historical","prominent","underlying","decisions","efficiently","abilities","microscope","outperform","everything","telescope","intelligence","laboratory","sensitivity","intervals","confidence","approximate","constitutes","necessity","approximations","computational","symmetric","approximating","obtaining","connection","eigenvalues","bottleneck","recording","published","resources","corresponding","associated","assessing","utterance","previously"],"y":[7,705,385,3,82,149,516,197,229,2,242,30,2,82,10,657,159,25,2,49,17,104,40,3,85,41,2,21,24,140,135,57,136,182,589,91,166,100,81,92,158,448,93,262,161,50,3,65,114,332,240,17,870,246,340,9,4,20,162,49,25,236,399,7,80,38,34,154,127,111,599,19,106,137,30,123,4,7,2,4,195,13,23,3,30,5,7,43,16,106,1,8,105,484,68,36,228,338,5,14,1,170,827,10,2,39,49,1,32,3,40,125,73,59,62,164,114,30,103,202,49,113,55,229,50,102,60,436,36,117,245,37,31,24,156,10,277,143,60,104,36,40,95,31,35,73,2,51,17,98,264,593,247,6,170,15,1,9,64,32,22,24,361,96,2,210,15,14,124,63,174,7,5,94,1,2,89,11,29,11,35,100,9,11,35,274,23,13,37,37,3,15,14,35,70,125,120,12,8,105],"type":"bar"},{"x":["postulates","different","representation","societies","represented","introduced","framework","prop ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4537,), (4537, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.815

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529412);'>Reasoning</span> <span style=''>System</span> <span style=''>for</span> <span style=''>a</span> <span style=''>First</span> <span style=''>Order</span> <span style=''>Logic</span> <span style=''>of</span> <span style=''>Limited</span> <span style=''>Belief</span> <br/><br/><span style=''>Logics</span> <span style=''>of</span> <span style=''>limited</span> <span style=''>belief</span> <span style=''>aim</span> <span style=''>at</span> <span style=''>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.33624454148471605);'>computationally</span> <span style=''>feasible</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529412);'>reasoning</span> <span style=''>in</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style='background-color:rgba(0, 255, 0, 0.42329020332717193);'>representation</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>languages</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>languages</span> <span style=''>are</span> <span style=''>often</span> <span style=''>dialects</span> <span style=''>of</span> <span style=''>first</span> <span style=''>order</span> <span style=''>logic</span> <span style=''>with</span> <span style=''>a</span> <span style=''>weaker</span> <span style=''>form</span> <span style=''>of</span> <span style=''>logical</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>entailment</span> <span style=''>that</span> <span style=''>keeps</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529412);'>reasoning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>decidable</span> <span style=''>or</span> <span style=''>even</span> <span style='background-color:rgba(255, 0, 0, 0.44444444444444453);'>tractable</span> <span style=''>While</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>such</span> <span style=''>logics</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>they</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>remain</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3119658119658119);'>theoretical</span> <span style=''>analysis</span> <span style=''>only</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relevance</span> <span style=''>is</span> <span style=''>very</span> <span style=''>limited</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>go</span> <span style=''>beyond</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>Building</span> <span style=''>on</span> <span style=''>earlier</span> <span style=''>work</span> <span style=''>by</span> <span style=''>Liu</span> <span style=''>Lakemeyer</span> <span style=''>and</span> <span style=''>Levesque</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>logic</span> <span style=''>of</span> <span style=''>limited</span> <span style=''>belief</span> <span style=''>that</span> <span style=''>is</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expressive</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>remaining</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>decidable</span> <span style=''>in</span> <span style=''>the</span> <span style=''>first</span> <span style=''>order</span> <span style=''>and</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separation</span> <span style=''>Theorem</span> <span style=''>for</span> <span style=''>Chain</span> <span style=''>Event</span> <span style=''>Graphs</span> <br/><br/><span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>(BNs)</span> <span style=''>are</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embodying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Much</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularity</span> <span style=''>is</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>d</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>theorem</span> <span style=''>of</span> <span style=''>Pearl</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lauritzen</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>an</span> <span style=''>analyst</span> <span style=''>to</span> <span style=''>identify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statements</span> <span style=''>that</span> <span style=''>a</span> <span style=''>model</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>embodies</span> <span style=''>using</span> <span style=''>only</span> <span style=''>the</span> <span style=''>topology</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>However</span> <span style=''>for</span> <span style=''>many</span> <span style=''>problems</span> <span style=''>the</span> <span style=''>complete</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>depicted</span> <span style=''>by</span> <span style=''>a</span> <span style=''>BN</span> <span style=''>The</span> <span style=''>Chain</span> <span style=''>Event</span> <span style=''>Graph</span> <span style=''>(CEG)</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>for</span> <span style=''>these</span> <span style=''>types</span> <span style=''>of</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>theorem</span> <span style=''>for</span> <span style=''>CEGs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analogous</span> <span style=''>to</span> <span style=''>the</span> <span style=''>d</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>theorem</span> <span style=''>for</span> <span style=''>BNs</span> <span style=''>which< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Connections</span> <span style=''>Between</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.36623376623376613);'>Stochastic</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Interesting</span> <span style='background-color:rgba(255, 0, 0, 0.3119658119658119);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associations</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>by</span> <span style=''>recent</span> <span style=''>papers</span> <span style=''>between</span> <span style=''>the</span> <span style=''>fields</span> <span style=''>of</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.36623376623376613);'>stochastic</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>common</span> <span style=''>role</span> <span style=''>of</span> <span style=''>feedback</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>querying</span> <span style='background-color:rgba(0, 255, 0, 0.42028985507246386);'>mechanisms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>continue</span> <span style=''>this</span> <span style=''>thread</span> <span style=''>in</span> <span style=''>two</span> <span style=''>parts</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.4796747967479674);'>relations</span> <span style=''>for</span> <span style=''>the</span> <span style=''>first</span> <span style=''>time</span> <span style=''>to</span> <span style=''>yield</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>both</span> <span style=''>fields</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivating</span> <span style=''>the</span> <span style=''>study</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3600000000000001);'>intersection</span> <span style=''>First</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>a</span> <span style=''>recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>was</span> <span style=''>adaptive</span> <span style=''>to</span> <span style=''>unknown</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.4090909090909091);'>convexity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>active</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.34285714285714286);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thresholds</span> <span style=''>that</span> <span style=''>can</span> <span style=''>yield</span> <span style=''>minimax</span> <span style=''>rates</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Active</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attributes</span> <span style=''>in</span> <span style=''>Networks</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style=''>networks</span> <span style=''>vertices</span> <span style=''>have</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>or</span> <span style=''>types</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>networks</span> <span style=''>topology</span> <span style=''>If</span> <span style=''>the</span> <span style=''>topology</span> <span style=''>is</span> <span style=''>known</span> <span style=''>but</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>are</span> <span style=''>not</span> <span style=''>and</span> <span style=''>if</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>is</span> <span style=''>costly</span> <span style=''>we</span> <span style=''>need</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style=''>choosing</span> <span style=''>which</span> <span style=''>vertex</span> <span style=''>to</span> <span style=''>query</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>as</span> <span style=''>much</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>of</span> <span style=''>the</span> <span style=''>other</span> <span style=''>vertices</span> <span style=''>We</span> <span style=''>assume</span> <span style=''>the</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>but</span> <span style=''>we</span> <span style=''>make</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>about</span> <span style=''>its</span> <span style=''>assortativity</span> <span style=''>or</span> <span style=''>disassortativity</span> <span style=''>We</span> <span style=''>choose</span> <span style=''>which</span> <span style=''>vertex</span> <span style=''>to</span> <span style=''>query</span> <span style=''>using</span> <span style=''>two</span> <span style=''>methods</span> <span style=''>1)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>between</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>and</span> <span style=''>those</span> <span style=''>of</span> <span style=''>the</span> <span style=''>others</span> <span style=''>(a</span> <span style=''>well</span> <span style=''>known</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>active</span> <span style=''>learning)</span> <span style=''>and</span> <span style=''>2)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style=''>average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>agreement</span> <span style=''>between</span> <span style=''>two</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0688802543270929)
# 	different (0.24902861179795124)
# 	architecture (0.08512892970681737)
# 	knowledge (0.1229247615683504)
# 	segmentation (0.07205934298834334)
# 	representation (0.13599434828682444)
# 	experimental (0.14411868597668667)
# 	detection (0.12009890498057224)
# 	convolutional (0.12751677852348994)
# 	recognition (0.14093959731543623)
#
# Some Statistics words are:
# 	stochastic (0.13357034027425088)
# 	variables (0.1350939563230066)
# 	estimation (0.1691213814118842)
# 	statistical (0.16099542915185372)
# 	theoretical (0.15591670898933468)
# 	distribution (0.1797866937531742)
# 	algorithm (0.4134078212290503)
# 	inference (0.20010157440325038)
# 	dimensional (0.1909598781107161)
# 	regression (0.18689690198070086)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ecf8921f-5c2e-4f1a-9b12-d5f3c106c743" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecf8921f-5c2e-4f1a-9b12-d5f3c106c743")) {                    Plotly.newPlot(                        "ecf8921f-5c2e-4f1a-9b12-d5f3c106c743",                        [{"x":["postulates","different","representation","societies","represented","introduced","framework","properties","functions","multisets","representations","independence","preorders","interesting","epistemic","information","understanding","alternatives","konieczny","operators","irrelevant","classical","extensions","conditionals","conditional","establish","impossibility","essentially","propositional","unsupervised","similarity","supervision","clustering","supervised","algorithms","procedure","constraints","typically","following","individual","selection","approaches","constraint","outperforms","generated","incorporate","clusterings","empirically","parameter","introduce","complexity","intervention","performance","challenging","detection","intention","progresses","dedicated","challenge","diversity","variability","significant","recognition","stimulate","strategies","difficulties","competition","solutions","challenges","regression","demonstrate","equations","increasing","resulting","differential","programming","truncated","propagate","differentiation","constants","automatic","presenting","differentiable","integrals","expressions","cartesian","polynomials","expression","dynamical","implemented","comprehensible","screening","extracted","classification","understand","predictive","application","important","differentiating","interpretability","cancerous","specifically","algorithm","interpreting","radiologist","requirements","diagnosis","multiparametric","visualization","reviewing","applicability","extraction","adaptation","evaluations","transform","classifier","distributions","procedures","embedding","distribution","validation","competitive","alignment","parameters","nonlinear","combining","comprehensive","efficient","quadratic","approximation","evaluation","superiority","stability","approximated","empirical","deviation","particular","computing","extension","structured","extending","situations","construct","scientific","factorization","construction","checkerboard","introducing","artifacts","mechanism","significantly","experiments","effective","reformulated","extensive","uncertainties","delivered","deconvolution","contribution","uncertain","favorably","encourage","convolutional","robustness","upsampling","inference","historical","prominent","underlying","decisions","efficiently","abilities","microscope","outperform","everything","telescope","intelligence","laboratory","sensitivity","intervals","confidence","approximate","constitutes","necessity","approximations","computational","symmetric","approximating","obtaining","connection","eigenvalues","bottleneck","recording","published","resources","corresponding","associated","assessing","utterance","previously","referenced","difficulty","relatedness","intelligent","dependent","transportation","transport","regularization","developed","prediction","inferring","complicated","interpretable","minimizing","experiment","reasonably","critically","processing","ensembles","divergence","synthetic","variables","probabilities","facilitates","isomorphism","optimization","linearized","benchmark","investigate","clustered","approximately","relations","furthermore","numerical","equivalently","encodings","effectiveness","multiplication","correlation","traditional","questions","bidirectional","overlapped","demonstrated","attention","answering","witnessed","interrelation","techniques","iteration","successful","achieving","explanation","thresholding","especially","additional","re ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	definiteness
# 	factorizes
# 	tibshirani
# 	wirtinger
# 	misspecification
# 	regressions
# 	supermarket
# 	seasonality
# 	chemicals
# 	timeseries
# 	subgroups
# 	interdependent
# 	postulated
# 	deviating
# 	permeates
# 	robustify
# 	robustification
# 	contingent
# 	oscillates
# 	similitude
# Some words which never appear in Statistics papers:
# 	postulates
# 	societies
# 	multisets
# 	preorders
# 	epistemic
# 	konieczny
# 	propositional
# 	stimulate
# 	cartesian
# 	checkerboard
# 	reformulated
# 	upsampling
# 	microscope
# 	utterance
# 	referenced
# 	interrelation
# 	distinctions
# 	reusability
# 	obstacles
# 	paraphrasing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0444180594879293e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
